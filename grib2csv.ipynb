# %%
import pandas as pd
import numpy as np
import xarray as xr
import os
import glob

def extract_era5_point_to_csv(region_name, lat, lon, creepmeter_id=None,
                               data_dir="./era5_data", out_dir="./era5_csv", overwrite=False):
    os.makedirs(out_dir, exist_ok=True)
    file_pattern = os.path.join(data_dir, f"era5_{region_name}_*.grib")
    file_list = sorted(glob.glob(file_pattern))

    if not file_list:
        print(f"Skipping {region_name}: no GRIB files found yet in {data_dir}")
        return None

    # Prepare output filename
    filename_base = creepmeter_id if creepmeter_id else f"{region_name}_lat{lat}_lon{lon}"
    csv_filename = f"{filename_base}_timeseries.csv"
    csv_path = os.path.join(out_dir, csv_filename)

    # Skip if already exists and overwrite is False
    if os.path.exists(csv_path) and not overwrite:
        print(f"Skipping {csv_filename}: file already exists.")
        return None

    all_data = []

    for f in file_list:
        print(f"Processing {os.path.basename(f)} for {filename_base}...")

        try:
            # Load total_precipitation with decode_timedelta set
            ds_tp = xr.open_dataset(
                f,
                engine="cfgrib",
                backend_kwargs={"filter_by_keys": {"shortName": "tp"}},
                decode_timedelta=True
            )
            ts_tp = ds_tp["tp"].sel(latitude=lat, longitude=lon, method="nearest").to_dataframe().reset_index()[["time", "tp"]]

            # Load surface_pressure with decode_timedelta set
            ds_sp = xr.open_dataset(
                f,
                engine="cfgrib",
                backend_kwargs={"filter_by_keys": {"shortName": "sp"}},
                decode_timedelta=True
            )
            ts_sp = ds_sp["sp"].sel(latitude=lat, longitude=lon, method="nearest").to_dataframe().reset_index()[["time", "sp"]]

            # Merge on time
            ts_merged = pd.merge(ts_tp, ts_sp, on="time")
            all_data.append(ts_merged)
        except Exception as e:
            print(f"Error reading {os.path.basename(f)}: {e}")
            continue

    if not all_data:
        print(f"No data could be extracted for {filename_base}")
        return None

    df_full = pd.concat(all_data).sort_values("time").reset_index(drop=True)
    df_full = df_full.rename(columns={"tp": "precipitation_m", "sp": "surface_pressure_pa"})
    df_full.to_csv(csv_path, index=False)
    print(f"Saved time series to {csv_path}")

    return df_full


# --- Main execution ---
Creepmeter_dataframe = pd.read_csv('../../Data/DATA_tidied/creepmeter_metadata_post_standardisation_sac_codes_updated.csv', index_col=0)
Creepmeter_dataframe.drop_duplicates('Creepmeter_abbrv', inplace=True)
Creepmeter_dataframe = Creepmeter_dataframe[~Creepmeter_dataframe['Creepmeter_abbrv'].isin(['XMBC', 'TABC'])].reset_index(drop=True)

regions = {
    'CAL': 'Hollister', 'CHAF': 'Pakistan', 'DSF': 'Israel', 'EAF': 'EAF',
    'HAY': 'Hayward', 'HOL': 'Hollister', 'NAF': 'NAF', 'PARK': 'Parkfield',
    'RID': 'Ridgecrest', 'SOCAL': 'SoCal', 'UTA': 'UTA'
}

Creepmeter_dataframe['Rain_region_file'] = Creepmeter_dataframe['Network'].map(regions)
rain_networks = np.unique(Creepmeter_dataframe['Rain_region_file'])

# Set this flag to control overwrite behaviour
OVERWRITE_EXISTING = False

for region in rain_networks:
    region_creepmeters = Creepmeter_dataframe[Creepmeter_dataframe['Rain_region_file'] == region]

    for _, row in region_creepmeters.iterrows():
        result = extract_era5_point_to_csv(
            region_name=region,
            lat=row['Latitude'],
            lon=row['Longitude'],
            creepmeter_id=row['Creepmeter_abbrv'],
            data_dir="./era5_data",
            out_dir="./era5_csv",
            overwrite=False
        )

        if result is None:
            print(f"Skipping creepmeter {row['Creepmeter_abbrv']} — no data or file already exists.")
# Out:
# Processing era5_EAF_2017_2020.grib for BAL1...
# Processing era5_EAF_2021_2024.grib for BAL1...
# Saved time series to ./era5_csv/BAL1_timeseries.csv
# Processing era5_EAF_2017_2020.grib for GOK1...
# Processing era5_EAF_2021_2024.grib for GOK1...
# Saved time series to ./era5_csv/GOK1_timeseries.csv
# Processing era5_EAF_2017_2020.grib for GOZ1...
# Processing era5_EAF_2021_2024.grib for GOZ1...
# Saved time series to ./era5_csv/GOZ1_timeseries.csv
# Processing era5_EAF_2017_2020.grib for HAS1...
# Processing era5_EAF_2021_2024.grib for HAS1...
# Saved time series to ./era5_csv/HAS1_timeseries.csv
# Processing era5_EAF_2017_2020.grib for HAT1...
# Processing era5_EAF_2021_2024.grib for HAT1...
# Saved time series to ./era5_csv/HAT1_timeseries.csv
# Processing era5_EAF_2017_2020.grib for KAR1...
# Processing era5_EAF_2021_2024.grib for KAR1...
# Saved time series to ./era5_csv/KAR1_timeseries.csv
# Processing era5_EAF_2017_2020.grib for KIR1...
# Processing era5_EAF_2021_2024.grib for KIR1...
# Saved time series to ./era5_csv/KIR1_timeseries.csv
# Processing era5_EAF_2017_2020.grib for ORM1...
# Processing era5_EAF_2021_2024.grib for ORM1...
# Saved time series to ./era5_csv/ORM1_timeseries.csv
# Processing era5_EAF_2017_2020.grib for PAN1...
# Processing era5_EAF_2021_2024.grib for PAN1...
# Saved time series to ./era5_csv/PAN1_timeseries.csv
# Processing era5_EAF_2017_2020.grib for PAS1...
# Processing era5_EAF_2021_2024.grib for PAS1...
# Saved time series to ./era5_csv/PAS1_timeseries.csv
# Processing era5_EAF_2017_2020.grib for SIV1...
# Processing era5_EAF_2021_2024.grib for SIV1...
# Saved time series to ./era5_csv/SIV1_timeseries.csv
# Processing era5_EAF_2017_2020.grib for TAS1...
# Processing era5_EAF_2021_2024.grib for TAS1...
# Saved time series to ./era5_csv/TAS1_timeseries.csv
# Processing era5_EAF_2017_2020.grib for YZE1...
# Processing era5_EAF_2021_2024.grib for YZE1...
# Saved time series to ./era5_csv/YZE1_timeseries.csv
# Processing era5_EAF_2017_2020.grib for YZW1...
# Processing era5_EAF_2021_2024.grib for YZW1...
# Saved time series to ./era5_csv/YZW1_timeseries.csv
# Processing era5_Hayward_1993_1996.grib for CFW1...
# Processing era5_Hayward_1997_2000.grib for CFW1...
# Processing era5_Hayward_2001_2004.grib for CFW1...
# Processing era5_Hayward_2005_2008.grib for CFW1...
# Processing era5_Hayward_2009_2012.grib for CFW1...
# Processing era5_Hayward_2013_2016.grib for CFW1...
# Processing era5_Hayward_2017_2020.grib for CFW1...
# Processing era5_Hayward_2021_2024.grib for CFW1...
# Saved time series to ./era5_csv/CFW1_timeseries.csv
# Processing era5_Hayward_1993_1996.grib for CHP1...
# Processing era5_Hayward_1997_2000.grib for CHP1...
# Processing era5_Hollister_2016_2019.grib for XSJ3...
# Processing era5_Hollister_2020_2023.grib for XSJ3...
# Processing era5_Hollister_2024_2024.grib for XSJ3...
# Saved time series to ./era5_csv/XSJ3_timeseries.csv
# Processing era5_Israel_2021_2024.grib for DS30...
# Saved time series to ./era5_csv/DS30_timeseries.csv
# Processing era5_NAF_2014_2017.grib for CER1...
# Processing era5_NAF_2018_2021.grib for CER1...
# Processing era5_NAF_2022_2024.grib for CER1...
# Saved time series to ./era5_csv/CER1_timeseries.csv
# Processing era5_NAF_2014_2017.grib for CHE1...
# Processing era5_NAF_2018_2021.grib for CHE1...
# Processing era5_NAF_2022_2024.grib for CHE1...
# Saved time series to ./era5_csv/CHE1_timeseries.csv
# Processing era5_NAF_2014_2017.grib for ESZ1...
# Processing era5_NAF_2018_2021.grib for ESZ1...
# Processing era5_NAF_2022_2024.grib for ESZ1...
# Saved time series to ./era5_csv/ESZ1_timeseries.csv
# Processing era5_NAF_2014_2017.grib for HAM1...
# Processing era5_NAF_2018_2021.grib for HAM1...
# Processing era5_NAF_2022_2024.grib for HAM1...
# Saved time series to ./era5_csv/HAM1_timeseries.csv
# Processing era5_NAF_2014_2017.grib for INW1...
# Processing era5_NAF_2018_2021.grib for INW1...
# Processing era5_NAF_2022_2024.grib for INW1...
# Saved time series to ./era5_csv/INW1_timeseries.csv
# Processing era5_NAF_2014_2017.grib for ISW1...
# Processing era5_NAF_2018_2021.grib for ISW1...
# Processing era5_NAF_2022_2024.grib for ISW1...
# Saved time series to ./era5_csv/ISW1_timeseries.csv
# Processing era5_NAF_2014_2017.grib for PET1...
# Processing era5_NAF_2018_2021.grib for PET1...
# Processing era5_NAF_2022_2024.grib for PET1...
# Saved time series to ./era5_csv/PET1_timeseries.csv
# Processing era5_NAF_2014_2017.grib for SEL1...
# Processing era5_NAF_2018_2021.grib for SEL1...
# Processing era5_NAF_2022_2024.grib for SEL1...
# Saved time series to ./era5_csv/SEL1_timeseries.csv
# Processing era5_NAF_2014_2017.grib for TEP1...
# Processing era5_NAF_2018_2021.grib for TEP1...
# Processing era5_NAF_2022_2024.grib for TEP1...
# Saved time series to ./era5_csv/TEP1_timeseries.csv
# Processing era5_NAF_2014_2017.grib for WSZ1...
# Processing era5_NAF_2018_2021.grib for WSZ1...
# Processing era5_NAF_2022_2024.grib for WSZ1...
# Saved time series to ./era5_csv/WSZ1_timeseries.csv
# Processing era5_Pakistan_2019_2021.grib for CHA1...
# Saved time series to ./era5_csv/CHA1_timeseries.csv
# Processing era5_Parkfield_1984_1987.grib for C461...
# Processing era5_Parkfield_1988_1991.grib for C461...
# Processing era5_Parkfield_1992_1995.grib for C461...
# Processing era5_Parkfield_1996_1999.grib for C461...
# Processing era5_Parkfield_2000_2003.grib for C461...
# Processing era5_Parkfield_2004_2007.grib for C461...
# Processing era5_Parkfield_2008_2011.grib for C461...
# Processing era5_Parkfield_2012_2015.grib for C461...
# Processing era5_Parkfield_2016_2019.grib for C461...
# Processing era5_Parkfield_2020_2023.grib for C461...
# Processing era5_Parkfield_2024_2024.grib for C461...
# Processing era5_Parkfield_2020_2023.grib for XGH1...
# Processing era5_Parkfield_2024_2024.grib for XGH1...
# Saved time series to ./era5_csv/XGH1_timeseries.csv
# Processing era5_Parkfield_1984_1987.grib for XHSW...
# Processing era5_Parkfield_1988_1991.grib for XHSW...
# Processing era5_Parkfield_1992_1995.grib for XHSW...
# Processing era5_Parkfield_1996_1999.grib for XHSW...
# Processing era5_Parkfield_2000_2003.grib for XHSW...
# Processing era5_Parkfield_2004_2007.grib for XHSW...
# Processing era5_Parkfield_2008_2011.grib for XHSW...
# Processing era5_Parkfield_2012_2015.grib for XHSW...
# Processing era5_Parkfield_2016_2019.grib for XHSW...
# Processing era5_Parkfield_2020_2023.grib for XHSW...
# Processing era5_Parkfield_2024_2024.grib for XHSW...
# Saved time series to ./era5_csv/XHSW_timeseries.csv
# Processing era5_Parkfield_1984_1987.grib for XMD1...
# Processing era5_Parkfield_1988_1991.grib for XMD1...
# Processing era5_Parkfield_1992_1995.grib for XMD1...
# Processing era5_Parkfield_1996_1999.grib for XMD1...
# Processing era5_Parkfield_2000_2003.grib for XMD1...
# Processing era5_Parkfield_2004_2007.grib for XMD1...
# Processing era5_Parkfield_2008_2011.grib for XMD1...
# Processing era5_Parkfield_2012_2015.grib for XMD1...
# Processing era5_Parkfield_2016_2019.grib for XMD1...
# Processing era5_Parkfield_2020_2023.grib for XMD1...
# Processing era5_Parkfield_2024_2024.grib for XMD1...
# Saved time series to ./era5_csv/XMD1_timeseries.csv
# Processing era5_Parkfield_1984_1987.grib for XMM1...
# Processing era5_Parkfield_1988_1991.grib for XMM1...
# Processing era5_Parkfield_1992_1995.grib for XMM1...
# Processing era5_Parkfield_1996_1999.grib for XMM1...
# Processing era5_Parkfield_2000_2003.grib for XMM1...
# Processing era5_Parkfield_2004_2007.grib for XMM1...
# Processing era5_Parkfield_2008_2011.grib for XMM1...
# Processing era5_Parkfield_2012_2015.grib for XMM1...
# Processing era5_Parkfield_2016_2019.grib for XMM1...
# Processing era5_Parkfield_2020_2023.grib for XMM1...
# Processing era5_Parkfield_2024_2024.grib for XMM1...
# Saved time series to ./era5_csv/XMM1_timeseries.csv
# Processing era5_Parkfield_1984_1987.grib for XPK1...
# Processing era5_Parkfield_1988_1991.grib for XPK1...
# Processing era5_Parkfield_1992_1995.grib for XPK1...
# Processing era5_Parkfield_1996_1999.grib for XPK1...
# Processing era5_Parkfield_2000_2003.grib for XPK1...
# Processing era5_Parkfield_2004_2007.grib for XPK1...
# Processing era5_Parkfield_2008_2011.grib for XPK1...
# Processing era5_Parkfield_2012_2015.grib for XPK1...
# Processing era5_Parkfield_2016_2019.grib for XPK1...
# Processing era5_Parkfield_2020_2023.grib for XPK1...
# Processing era5_Parkfield_2024_2024.grib for XPK1...
# Saved time series to ./era5_csv/XPK1_timeseries.csv
# Processing era5_Parkfield_1984_1987.grib for XPK2...
# Processing era5_Parkfield_1988_1991.grib for XPK2...
# Processing era5_Parkfield_1992_1995.grib for XPK2...
# Processing era5_Parkfield_1996_1999.grib for XPK2...
# Processing era5_Parkfield_2000_2003.grib for XPK2...
# Processing era5_SoCal_2004_2007.grib for RR45...
# Processing era5_SoCal_2008_2011.grib for RR45...
# Processing era5_SoCal_2012_2015.grib for RR45...
# Processing era5_SoCal_2016_2019.grib for RR45...
# Processing era5_SoCal_2020_2023.grib for RR45...
# Processing era5_SoCal_2024_2024.grib for RR45...
# Saved time series to ./era5_csv/RR45_timeseries.csv
# Processing era5_SoCal_2004_2007.grib for SC30...
# Processing era5_SoCal_2008_2011.grib for SC30...
# Processing era5_SoCal_2012_2015.grib for SC30...
# Processing era5_SoCal_2016_2019.grib for SC30...
# Processing era5_SoCal_2020_2023.grib for SC30...
# Processing era5_SoCal_2024_2024.grib for SC30...
# Saved time series to ./era5_csv/SC30_timeseries.csv
# Processing era5_SoCal_2004_2007.grib for SH30...
# Processing era5_SoCal_2008_2011.grib for SH30...
# Processing era5_SoCal_2012_2015.grib for SH30...
# Processing era5_SoCal_2016_2019.grib for SH30...
# Processing era5_SoCal_2020_2023.grib for SH30...
# Processing era5_SoCal_2024_2024.grib for SH30...
# Saved time series to ./era5_csv/SH30_timeseries.csv
# Processing era5_SoCal_2004_2007.grib for SU30...
# Processing era5_SoCal_2008_2011.grib for SU30...
# Processing era5_SoCal_2012_2015.grib for SU30...
# Processing era5_SoCal_2016_2019.grib for SU30...
# Processing era5_SoCal_2020_2023.grib for SU30...
# Processing era5_SoCal_2024_2024.grib for SU30...
# Saved time series to ./era5_csv/SU30_timeseries.csv
# Processing era5_SoCal_2004_2007.grib for COML...
# Processing era5_SoCal_2008_2011.grib for COML...
# Processing era5_SoCal_2012_2015.grib for COML...
# Processing era5_SoCal_2016_2019.grib for COML...
# Processing era5_SoCal_2020_2023.grib for COML...
# Processing era5_SoCal_2024_2024.grib for COML...
# Saved time series to ./era5_csv/COML_timeseries.csv
# Processing era5_SoCal_2004_2007.grib for COLE...
# Processing era5_SoCal_2008_2011.grib for COLE...
# Processing era5_SoCal_2012_2015.grib for COLE...
# Processing era5_SoCal_2016_2019.grib for COLE...
# Processing era5_SoCal_2020_2023.grib for COLE...
# Processing era5_SoCal_2024_2024.grib for COLE...
# Saved time series to ./era5_csv/COLE_timeseries.csv
# Processing era5_SoCal_2004_2007.grib for COLW...
# Processing era5_SoCal_2008_2011.grib for COLW...
# Processing era5_SoCal_2012_2015.grib for COLW...
# Processing era5_SoCal_2016_2019.grib for COLW...
# Processing era5_SoCal_2020_2023.grib for COLW...
# Processing era5_SoCal_2024_2024.grib for COLW...
# Saved time series to ./era5_csv/COLW_timeseries.csv
# Processing era5_SoCal_2004_2007.grib for EASH...
# Processing era5_SoCal_2008_2011.grib for EASH...
# Processing era5_SoCal_2012_2015.grib for EASH...
# Processing era5_SoCal_2016_2019.grib for EASH...
# Processing era5_SoCal_2020_2023.grib for EASH...
# Processing era5_SoCal_2024_2024.grib for EASH...
# Saved time series to ./era5_csv/EASH_timeseries.csv
# Skipping UTA: no GRIB files found yet in ./era5_data
# Skipping creepmeter CAN1 — no data or file already exists.

# %%
def extract_era5_point_to_csv(region_name, lat, lon, data_dir="./era5_data", out_dir="./era5_csv"):
    os.makedirs(out_dir, exist_ok=True)
    file_pattern = os.path.join(data_dir, f"era5_{region_name}_*.grib")
    file_list = sorted(glob.glob(file_pattern))

    if not file_list:
        raise FileNotFoundError(f"No GRIB files found for region '{region_name}' in {data_dir}")

    all_data = []

    for f in file_list:
        print(f"Processing {os.path.basename(f)}...")

        # Load total_precipitation
        ds_tp = xr.open_dataset(f, engine="cfgrib", backend_kwargs={"filter_by_keys": {"shortName": "tp"}})
        ts_tp = ds_tp["tp"].sel(latitude=lat, longitude=lon, method="nearest").to_dataframe().reset_index()[["time", "tp"]]

        # Load surface_pressure
        ds_sp = xr.open_dataset(f, engine="cfgrib", backend_kwargs={"filter_by_keys": {"shortName": "sp"}})
        ts_sp = ds_sp["sp"].sel(latitude=lat, longitude=lon, method="nearest").to_dataframe().reset_index()[["time", "sp"]]

        # Merge on time
        ts_merged = pd.merge(ts_tp, ts_sp, on="time")
        all_data.append(ts_merged)

    # Combine all chunks
    df_full = pd.concat(all_data).sort_values("time").reset_index(drop=True)
    df_full = df_full.rename(columns={"tp": "precipitation_m", "sp": "surface_pressure_pa"})

    # Save to CSV
    csv_filename = f"{region_name}_lat{lat}_lon{lon}_timeseries.csv".replace(".", "p")
    csv_path = os.path.join(out_dir, csv_filename)
    #df_full.to_csv(csv_path, index=False)
    print(f"Saved time series to {csv_path}")

    return df_full

# %%
Creepmeter_dataframe = pd.read_csv('../../Data/DATA_tidied/creepmeter_metadata_post_standardisation_sac_codes_updated.csv',index_col=0)
Creepmeter_dataframe.drop_duplicates('Creepmeter_abbrv',inplace=True)
Creepmeter_dataframe.drop(Creepmeter_dataframe[Creepmeter_dataframe['Creepmeter_abbrv']=='XMBC'].index,inplace=True)
Creepmeter_dataframe.drop(Creepmeter_dataframe[Creepmeter_dataframe['Creepmeter_abbrv']=='TABC'].index,inplace=True)
Creepmeter_dataframe.reset_index(inplace=True,drop=True)

regions = {'CAL':'Hollister', 'CHAF':'Pakistan', 'DSF':'Israel','EAF':'EAF', 'HAY':'Hayward', 'HOL':'Hollister', 'NAF':'NAF',
            'PARK':'Parkfield', 'RID':'Ridgecrest','SOCAL':'SoCal', 'UTA':'UTA'}

regions_rain = []
for i in range(len(Creepmeter_dataframe)):
    rain_file = regions[Creepmeter_dataframe['Network'].iloc[i]]
    regions_rain.append(rain_file)
Creepmeter_dataframe['Rain_region_file'] = regions_rain

# %%
rain_networks = np.unique(Creepmeter_dataframe['Rain_region_file'])

# %%
for i in range(len(rain_networks)):
    creepmeters_in_region = Creepmeter_dataframe.drop(Creepmeter_dataframe[Creepmeter_dataframe['Rain_region_file']!=rain_networks[i]].index)
    for j in range(len(creepmeters_in_region)):
        df = extract_era5_point_to_csv(region_name=rain_networks[i],lat=creepmeters_in_region['Latitude'].iloc[j],
                                       lon=creepmeters_in_region['Longitude'].iloc[j],data_dir="./era5_data",out_dir="./era5_csv", overwrite=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       2 creepmeters_in_region = Creepmeter_dataframe.drop(Creepmeter_dataframe[Creepmeter_dataframe['Rain_region_file']!=rain_networks[i]].index)
#       3 for j in range(len(creepmeters_in_region)):
# ----> 4     df = extract_era5_point_to_csv(region_name=rain_networks[i],lat=creepmeters_in_region['Latitude'].iloc[j],
#       5                                    lon=creepmeters_in_region['Longitude'].iloc[j],data_dir="./era5_data",out_dir="./era5_csv", overwrite=True)
#
# TypeError: extract_era5_point_to_csv() got an unexpected keyword argument 'overwrite'

# %%
df = extract_era5_point_to_csv(
    region_name="Hollister",
    lat=36.75,
    lon=-121.25,
    data_dir="./era5_data",
    out_dir="./era5_csv"
)

print(df.head())
# Out:
# Processing era5_Hollister_1980_1983.grib...
# /Users/dagi9522/miniconda3/envs/Aseismic/lib/python3.10/site-packages/cfgrib/xarray_plugin.py:131: FutureWarning: In a future version, xarray will not decode timedelta values based on the presence of a timedelta-like units attribute by default. Instead it will rely on the presence of a timedelta64 dtype attribute, which is now xarray's default way of encoding timedelta64 values. To continue decoding timedeltas based on the presence of a timedelta-like units attribute, users will need to explicitly opt-in by passing True or CFTimedeltaCoder(decode_via_units=True) to decode_timedelta. To silence this warning, set decode_timedelta to True, False, or a 'CFTimedeltaCoder' instance.
#   vars, attrs, coord_names = xr.conventions.decode_cf_variables(
# /Users/dagi9522/miniconda3/envs/Aseismic/lib/python3.10/site-packages/cfgrib/xarray_plugin.py:131: FutureWarning: In a future version, xarray will not decode timedelta values based on the presence of a timedelta-like units attribute by default. Instead it will rely on the presence of a timedelta64 dtype attribute, which is now xarray's default way of encoding timedelta64 values. To continue decoding timedeltas based on the presence of a timedelta-like units attribute, users will need to explicitly opt-in by passing True or CFTimedeltaCoder(decode_via_units=True) to decode_timedelta. To silence this warning, set decode_timedelta to True, False, or a 'CFTimedeltaCoder' instance.
#   vars, attrs, coord_names = xr.conventions.decode_cf_variables(
# Processing era5_Hollister_1984_1987.grib...
# /Users/dagi9522/miniconda3/envs/Aseismic/lib/python3.10/site-packages/cfgrib/xarray_plugin.py:131: FutureWarning: In a future version, xarray will not decode timedelta values based on the presence of a timedelta-like units attribute by default. Instead it will rely on the presence of a timedelta64 dtype attribute, which is now xarray's default way of encoding timedelta64 values. To continue decoding timedeltas based on the presence of a timedelta-like units attribute, users will need to explicitly opt-in by passing True or CFTimedeltaCoder(decode_via_units=True) to decode_timedelta. To silence this warning, set decode_timedelta to True, False, or a 'CFTimedeltaCoder' instance.
#   vars, attrs, coord_names = xr.conventions.decode_cf_variables(
# /Users/dagi9522/miniconda3/envs/Aseismic/lib/python3.10/site-packages/cfgrib/xarray_plugin.py:131: FutureWarning: In a future version, xarray will not decode timedelta values based on the presence of a timedelta-like units attribute by default. Instead it will rely on the presence of a timedelta64 dtype attribute, which is now xarray's default way of encoding timedelta64 values. To continue decoding timedeltas based on the presence of a timedelta-like units attribute, users will need to explicitly opt-in by passing True or CFTimedeltaCoder(decode_via_units=True) to decode_timedelta. To silence this warning, set decode_timedelta to True, False, or a 'CFTimedeltaCoder' instance.
#   vars, attrs, coord_names = xr.conventions.decode_cf_variables(
# Processing era5_Hollister_1992_1995.grib...
# /Users/dagi9522/miniconda3/envs/Aseismic/lib/python3.10/site-packages/cfgrib/xarray_plugin.py:131: FutureWarning: In a future version, xarray will not decode timedelta values based on the presence of a timedelta-like units attribute by default. Instead it will rely on the presence of a timedelta64 dtype attribute, which is now xarray's default way of encoding timedelta64 values. To continue decoding timedeltas based on the presence of a timedelta-like units attribute, users will need to explicitly opt-in by passing True or CFTimedeltaCoder(decode_via_units=True) to decode_timedelta. To silence this warning, set decode_timedelta to True, False, or a 'CFTimedeltaCoder' instance.
#   vars, attrs, coord_names = xr.conventions.decode_cf_variables(
# /Users/dagi9522/miniconda3/envs/Aseismic/lib/python3.10/site-packages/cfgrib/xarray_plugin.py:131: FutureWarning: In a future version, xarray will not decode timedelta values based on the presence of a timedelta-like units attribute by default. Instead it will rely on the presence of a timedelta64 dtype attribute, which is now xarray's default way of encoding timedelta64 values. To continue decoding timedeltas based on the presence of a timedelta-like units attribute, users will need to explicitly opt-in by passing True or CFTimedeltaCoder(decode_via_units=True) to decode_timedelta. To silence this warning, set decode_timedelta to True, False, or a 'CFTimedeltaCoder' instance.
#   vars, attrs, coord_names = xr.conventions.decode_cf_variables(
# Saved time series to ./era5_csv/Hollister_lat36p75_lon-121p25_timeseriespcsv
#                  time         step_tp  number_tp  surface_tp  latitude_tp  \
# 0 1980-01-01 06:00:00 0 days 01:00:00          0         0.0        36.75
# 1 1980-01-01 06:00:00 0 days 12:00:00          0         0.0        36.75
# 2 1980-01-01 06:00:00 0 days 11:00:00          0         0.0        36.75
# 3 1980-01-01 06:00:00 0 days 10:00:00          0         0.0        36.75
# 4 1980-01-01 06:00:00 0 days 08:00:00          0         0.0        36.75
#
#    longitude_tp       valid_time_tp        tp  number_sp step_sp  surface_sp  \
# 0       -121.25 1980-01-01 07:00:00  0.000003          0  0 days         0.0
# 1       -121.25 1980-01-01 18:00:00  0.000004          0  0 days         0.0
# 2       -121.25 1980-01-01 17:00:00  0.000002          0  0 days         0.0
# 3       -121.25 1980-01-01 16:00:00  0.000005          0  0 days         0.0
# 4       -121.25 1980-01-01 14:00:00  0.000000          0  0 days         0.0
#
#    latitude_sp  longitude_sp       valid_time_sp         sp
# 0        36.75       -121.25 1980-01-01 06:00:00  97621.625
# 1        36.75       -121.25 1980-01-01 06:00:00  97621.625
# 2        36.75       -121.25 1980-01-01 06:00:00  97621.625
# 3        36.75       -121.25 1980-01-01 06:00:00  97621.625
# 4        36.75       -121.25 1980-01-01 06:00:00  97621.625

# %%
print(Creepmeter_dataframe)
# Out:
#    Network Creepmeter_abbrv File_code                   Start Time  \
# 0      EAF             BAL1   BAL1_1T  2023-03-12T10:47:55.000000Z
# 1     PARK             C461  C461_10T  2004-09-29T02:20:00.000000Z
# 2     PARK             C462   C462_1T  2021-08-19T19:10:11.000000Z
# 3      UTA             CAN1  CAN1_30T  2012-06-12T15:33:00.000000Z
# 4      NAF             CER1  CER1_30S  2019-10-09T06:46:00.000000Z
# ..     ...              ...       ...                          ...
# 73     EAF             YZW1   YZW1_1T  2023-03-22T10:59:37.000000Z
# 74   SOCAL             COML  COML_30T          2010-08-15T00:30:00
# 75   SOCAL             COLE  COLE_30T          2010-08-10T07:01:56
# 76   SOCAL             COLW   COLW_5T          2010-04-10T00:10:00
# 77   SOCAL             EASH   EASH_5T          2016-12-30T19:47:39
#
#                        End Time  Sampling rate, Hz Sampling rate, mins  \
# 0   2023-09-05T13:14:55.000000Z           0.016667                  1T
# 1   2022-06-20T12:40:00.000000Z           0.001667                 10T
# 2   2024-03-22T01:05:11.000000Z           0.016667                  1T
# 3   2017-06-15T08:33:00.000000Z           0.000556                 30T
# 4   2024-05-23T10:25:30.000000Z           0.033333                 30S
# ..                          ...                ...                 ...
# 73  2024-05-26T14:10:37.000000Z           0.016667                  1T
# 74          2011-02-03T16:55:05           0.000556                 30T
# 75          2011-02-20T20:31:56           0.000556                 30T
# 76          2010-04-16T17:40:00           0.003333                  5T
# 77          2024-11-27T19:34:56           0.003333                  5T
#
#     Latitude  Longitude Length Depth  Obliquity   Creepmeter_full_name  \
# 0    37.9903    38.1990    5 m   NaN       30.0             Balikburnu
# 1    35.7240  -120.2820    NaN   NaN       30.0             Highway 46
# 2    35.7240  -120.2820    NaN   NaN       30.0             Highway 46
# 3    38.0198  -110.0374  7.5 m   NaN       45.0            Canyonlands
# 4    40.8947    32.7773   20 m   NaN       29.0                 Cerkes
# ..       ...        ...    ...   ...        ...                    ...
# 73   38.1086    38.7361    5 m   NaN       35.0            Yazica West
# 74   33.8965  -117.0866    NaN   NaN       30.0            Mystic Lake
# 75   32.6643  -115.8790    NaN   NaN       30.0              Yuha East
# 76   32.6483  -115.8480    NaN   NaN       30.0              Yuha West
# 77   33.3710  -115.7801    NaN   NaN       53.0  East Shoreline Normal
#
#                                     Fault
# 0                    East Anatolian Fault
# 1           San Andraes Fault - Parkfield
# 2           San Andraes Fault - Parkfield
# 3   Southern Imperial Valley Fault - Utah
# 4                   North Anatolian Fault
# ..                                    ...
# 73                   East Anatolian Fault
# 74                      San Jacinto Fault
# 75                    Laguna Salada Fault
# 76                    Laguna Salada Fault
# 77                   East Shoreline Fault
#
# [78 rows x 14 columns]

# %%
# Out:
# array(['CAL', 'CHAF', 'DSF', 'EAF', 'HAY', 'HOL', 'NAF', 'PARK', 'RID',
#        'SOCAL', 'UTA'], dtype=object)

# %%
regions['HAY']
# Out:
# 'Hayward'

# %%
# Out:
# EAF
# Parkfield
# Parkfield
# UTA
# NAF
# Hayward
# Pakistan
# NAF
# Hayward
# Hayward
# Hayward
# Parkfield
# Hayward
# Hollister
# Hollister
# Israel
# SoCal
# NAF
# Hollister
# SoCal
# Ridgecrest
# Ridgecrest
# EAF
# EAF
# Ridgecrest
# NAF
# EAF
# EAF
# NAF
# SoCal
# NAF
# EAF
# EAF
# SoCal
# EAF
# EAF
# EAF
# NAF
# SoCal
# SoCal
# Ridgecrest
# Ridgecrest
# Ridgecrest
# SoCal
# SoCal
# NAF
# SoCal
# EAF
# Hollister
# SoCal
# EAF
# NAF
# Parkfield
# NAF
# Parkfield
# Parkfield
# Hollister
# Hollister
# Hollister
# Parkfield
# Parkfield
# Parkfield
# Hollister
# Parkfield
# Parkfield
# Parkfield
# Parkfield
# Hollister
# Hollister
# Hollister
# Parkfield
# Parkfield
# EAF
# EAF
# SoCal
# SoCal
# SoCal
# SoCal
